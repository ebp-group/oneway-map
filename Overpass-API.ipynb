# %%
import overpass
from utils import sparql
import os
import json

# %%
api = overpass.API(timeout=4000)

# %%
# get all countries in Europe from Wikidata

# get list of swiss municipalities incl. zip code
query = """
SELECT ?countryLabel ?country ?isoCode
{
  # ?country wdt:P31 wd:Q6256 .
  # ?country wdt:P30 wd:Q46 .
  # ?country wdt:P297 ?isoCode .
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en" }
}
ORDER BY ?countryLabel
"""

result = sparql.query(query, endpoint="https://query.wikidata.org/sparql")
european_countries = [{k: v['value'] for k,v in m.items()} for m in result]

european_countries
# Out:
# [{'country': 'http://www.wikidata.org/entity/Q222',
#   'isoCode': 'AL',
#   'countryLabel': 'Albania'},
#  {'country': 'http://www.wikidata.org/entity/Q228',
#   'isoCode': 'AD',
#   'countryLabel': 'Andorra'},
#  {'country': 'http://www.wikidata.org/entity/Q40',
#   'isoCode': 'AT',
#   'countryLabel': 'Austria'},
#  {'country': 'http://www.wikidata.org/entity/Q184',
#   'isoCode': 'BY',
#   'countryLabel': 'Belarus'},
#  {'country': 'http://www.wikidata.org/entity/Q31',
#   'isoCode': 'BE',
#   'countryLabel': 'Belgium'},
#  {'country': 'http://www.wikidata.org/entity/Q225',
#   'isoCode': 'BA',
#   'countryLabel': 'Bosnia and Herzegovina'},
#  {'country': 'http://www.wikidata.org/entity/Q219',
#   'isoCode': 'BG',
#   'countryLabel': 'Bulgaria'},
#  {'country': 'http://www.wikidata.org/entity/Q224',
#   'isoCode': 'HR',
#   'countryLabel': 'Croatia'},
#  {'country': 'http://www.wikidata.org/entity/Q229',
#   'isoCode': 'CY',
#   'countryLabel': 'Cyprus'},
#  {'country': 'http://www.wikidata.org/entity/Q213',
#   'isoCode': 'CZ',
#   'countryLabel': 'Czech Republic'},
#  {'country': 'http://www.wikidata.org/entity/Q35',
#   'isoCode': 'DK',
#   'countryLabel': 'Denmark'},
#  {'country': 'http://www.wikidata.org/entity/Q191',
#   'isoCode': 'EE',
#   'countryLabel': 'Estonia'},
#  {'country': 'http://www.wikidata.org/entity/Q33',
#   'isoCode': 'FI',
#   'countryLabel': 'Finland'},
#  {'country': 'http://www.wikidata.org/entity/Q142',
#   'isoCode': 'FR',
#   'countryLabel': 'France'},
#  {'country': 'http://www.wikidata.org/entity/Q183',
#   'isoCode': 'DE',
#   'countryLabel': 'Germany'},
#  {'country': 'http://www.wikidata.org/entity/Q41',
#   'isoCode': 'GR',
#   'countryLabel': 'Greece'},
#  {'country': 'http://www.wikidata.org/entity/Q28',
#   'isoCode': 'HU',
#   'countryLabel': 'Hungary'},
#  {'country': 'http://www.wikidata.org/entity/Q189',
#   'isoCode': 'IS',
#   'countryLabel': 'Iceland'},
#  {'country': 'http://www.wikidata.org/entity/Q27',
#   'isoCode': 'IE',
#   'countryLabel': 'Ireland'},
#  {'country': 'http://www.wikidata.org/entity/Q38',
#   'isoCode': 'IT',
#   'countryLabel': 'Italy'},
#  {'country': 'http://www.wikidata.org/entity/Q29999',
#   'isoCode': 'NL',
#   'countryLabel': 'Kingdom of the Netherlands'},
#  {'country': 'http://www.wikidata.org/entity/Q1246',
#   'isoCode': 'XK',
#   'countryLabel': 'Kosovo'},
#  {'country': 'http://www.wikidata.org/entity/Q211',
#   'isoCode': 'LV',
#   'countryLabel': 'Latvia'},
#  {'country': 'http://www.wikidata.org/entity/Q347',
#   'isoCode': 'LI',
#   'countryLabel': 'Liechtenstein'},
#  {'country': 'http://www.wikidata.org/entity/Q37',
#   'isoCode': 'LT',
#   'countryLabel': 'Lithuania'},
#  {'country': 'http://www.wikidata.org/entity/Q32',
#   'isoCode': 'LU',
#   'countryLabel': 'Luxembourg'},
#  {'country': 'http://www.wikidata.org/entity/Q233',
#   'isoCode': 'MT',
#   'countryLabel': 'Malta'},
#  {'country': 'http://www.wikidata.org/entity/Q236',
#   'isoCode': 'ME',
#   'countryLabel': 'Montenegro'},
#  {'country': 'http://www.wikidata.org/entity/Q221',
#   'isoCode': 'MK',
#   'countryLabel': 'North Macedonia'},
#  {'country': 'http://www.wikidata.org/entity/Q20',
#   'isoCode': 'NO',
#   'countryLabel': 'Norway'},
#  {'country': 'http://www.wikidata.org/entity/Q36',
#   'isoCode': 'PL',
#   'countryLabel': 'Poland'},
#  {'country': 'http://www.wikidata.org/entity/Q45',
#   'isoCode': 'PT',
#   'countryLabel': 'Portugal'},
#  {'country': 'http://www.wikidata.org/entity/Q218',
#   'isoCode': 'RO',
#   'countryLabel': 'Romania'},
#  {'country': 'http://www.wikidata.org/entity/Q159',
#   'isoCode': 'RU',
#   'countryLabel': 'Russia'},
#  {'country': 'http://www.wikidata.org/entity/Q214',
#   'isoCode': 'SK',
#   'countryLabel': 'Slovakia'},
#  {'country': 'http://www.wikidata.org/entity/Q215',
#   'isoCode': 'SI',
#   'countryLabel': 'Slovenia'},
#  {'country': 'http://www.wikidata.org/entity/Q29',
#   'isoCode': 'ES',
#   'countryLabel': 'Spain'},
#  {'country': 'http://www.wikidata.org/entity/Q34',
#   'isoCode': 'SE',
#   'countryLabel': 'Sweden'},
#  {'country': 'http://www.wikidata.org/entity/Q39',
#   'isoCode': 'CH',
#   'countryLabel': 'Switzerland'},
#  {'country': 'http://www.wikidata.org/entity/Q145',
#   'isoCode': 'GB',
#   'countryLabel': 'United Kingdom'},
#  {'country': 'http://www.wikidata.org/entity/Q237',
#   'isoCode': 'VA',
#   'countryLabel': 'Vatican City'}]

# %%
for country in european_countries:
    gj_path = os.path.join("oneway_countries", f"Oneway_{country['isoCode']}.geojson")
    if os.path.exists(gj_path):
        continue
    query = f'''
    rel["ISO3166-1:alpha2"="{country['isoCode']}"]["boundary"="administrative"];
    map_to_area;
    way["highway"!="motorway"]["highway"!="trunk"]["highway"!="primary_link"][!"tramway"]["oneway"="yes"](area);
    out geom;
    '''
    print(query)
    try:
        response = api.get(query, responseformat="geojson")
    except overpass.OverpassError as e:
        print(f"Error: {e}")
        continue
    print(f"Found {len(response['features'])} features.")
    with open(gj_path, "w") as f:
        f.write(json.dumps(response, indent=4))
response
# Out:
#     rel["ISO3166-1:alpha2"="FR"]["boundary"="administrative"];
#     map_to_area;
#     way["highway"!="motorway"]["highway"!="trunk"]["highway"!="primary_link"][!"tramway"]["oneway"="yes"](area);
#     out geom;
#
# Error: runtime error: Query timed out in "print" at line 5 after 192 seconds.
#
#     rel["ISO3166-1:alpha2"="DE"]["boundary"="administrative"];
#     map_to_area;
#     way["highway"!="motorway"]["highway"!="trunk"]["highway"!="primary_link"][!"tramway"]["oneway"="yes"](area);
#     out geom;
#
# Found 637337 features.
#
#     rel["ISO3166-1:alpha2"="LU"]["boundary"="administrative"];
#     map_to_area;
#     way["highway"!="motorway"]["highway"!="trunk"]["highway"!="primary_link"][!"tramway"]["oneway"="yes"](area);
#     out geom;
#
# Found 8671 features.
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4015956,
#     'tags': {'highway': 'motorway_link',
#      'int_ref': 'E 29',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '90',
#      'oneway': 'yes',
#      'operator': 'Administration des Ponts et Chaussées',
#      'ref': 'A 3',
#      'surface': 'asphalt',
#      'toll': 'no',
#      'zone:traffic': 'LU:motorway'},
#     'nodes': [141829, 339585459, 141839, 1348949737, 339582370, 141838]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.1277538, 49.577355],
#      [6.1274553, 49.5776267],
#      [6.1270879, 49.5778557],
#      [6.1267235, 49.5780156],
#      [6.1264469, 49.5781177],
#      [6.1260389, 49.5782316]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4015957,
#     'tags': {'bicycle': 'no',
#      'foot': 'no',
#      'hgv': 'yes',
#      'highway': 'motorway_link',
#      'int_ref': 'E 29',
#      'lanes': '2',
#      'lit': 'yes',
#      'maxspeed': '90',
#      'minspeed': '40',
#      'moped': 'no',
#      'oneway': 'yes',
#      'operator': 'Administration des Ponts et Chaussées',
#      'ref': 'A 3',
#      'surface': 'asphalt',
#      'toll': 'no',
#      'zone:traffic': 'LU:motorway'},
#     'nodes': [4105818471,
#      339582366,
#      21277352,
#      339586493,
#      141836,
#      21277355,
#      1851267642,
#      21277356,
#      1851267641]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.1243533, 49.5783981],
#      [6.1241359, 49.5783922],
#      [6.1237008, 49.5783573],
#      [6.1233018, 49.5783015],
#      [6.1229215, 49.5782349],
#      [6.1225281, 49.5781319],
#      [6.1222379, 49.5780242],
#      [6.1220146, 49.5779123],
#      [6.1218515, 49.5778104]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4015960,
#     'tags': {'bicycle': 'no',
#      'bridge': 'yes',
#      'destination:lanes': 'Luxembourg-Centre;Strassen|Trier;Metz;Esch/Alzette',
#      'destination:ref:lanes': 'N 6|A 6;E 25',
#      'foot': 'no',
#      'highway': 'motorway_link',
#      'junction:ref': '4',
#      'lanes': '2',
#      'layer': '1',
#      'lit': 'yes',
#      'minspeed': '40',
#      'moped': 'no',
#      'oneway': 'yes',
#      'ref': 'A 6',
#      'surface': 'asphalt',
#      'toll': 'no'},
#     'nodes': [21277390, 6076300642, 4007776509]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0836088, 49.6205648],
#      [6.0834244, 49.6205502],
#      [6.0829054, 49.6204927]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4015961,
#     'tags': {'destination': 'Trier;Metz;Esch/Alzette',
#      'destination:ref': 'A 6;E 25',
#      'destination:symbol': 'airport',
#      'highway': 'motorway_link',
#      'junction:ref': '4',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '130',
#      'maxspeed:conditional': '110 @ wet',
#      'maxspeed:hgv:conditional': '90 @ (weight>7.5)',
#      'oneway': 'yes',
#      'ref': 'A 6',
#      'surface': 'asphalt',
#      'toll': 'no'},
#     'nodes': [4007776509,
#      361353923,
#      21277391,
#      21277392,
#      141624,
#      21277401,
#      21277393,
#      361353924,
#      21277394,
#      21277395,
#      141628,
#      21277396,
#      21277397,
#      141629,
#      2046003568,
#      361353926,
#      21277398,
#      361353928]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0829054, 49.6204927],
#      [6.0825867, 49.6204853],
#      [6.0823811, 49.6204978],
#      [6.0821748, 49.6205489],
#      [6.081989, 49.6206807],
#      [6.0818518, 49.6208204],
#      [6.0817325, 49.6209791],
#      [6.0816942, 49.6211413],
#      [6.0817135, 49.6212749],
#      [6.081802, 49.6214031],
#      [6.0819825, 49.6214962],
#      [6.082204, 49.6215357],
#      [6.0824098, 49.6215108],
#      [6.0825851, 49.621434],
#      [6.0826522, 49.6213851],
#      [6.0827138, 49.6213378],
#      [6.0827903, 49.621235],
#      [6.0828753, 49.621081]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4015981,
#     'tags': {'highway': 'motorway_link',
#      'int_ref': 'E 25',
#      'lanes': '2',
#      'lit': 'yes',
#      'maxspeed': '90',
#      'oneway': 'yes',
#      'operator': 'Administration des Ponts et Chaussées',
#      'ref': 'A 3',
#      'surface': 'asphalt',
#      'toll': 'no',
#      'zone:traffic': 'LU:motorway'},
#     'nodes': [141843,
#      2571990371,
#      1783253009,
#      21277379,
#      21277380,
#      21277381,
#      364491355]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.1236135, 49.5738889],
#      [6.1237028, 49.5737848],
#      [6.1237843, 49.5736932],
#      [6.1240362, 49.5733822],
#      [6.1244012, 49.5728196],
#      [6.1246812, 49.5722967],
#      [6.1249776, 49.5716333]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4016002,
#     'tags': {'bicycle': 'no',
#      'foot': 'no',
#      'hgv': 'yes',
#      'highway': 'motorway_link',
#      'junction:ref': '2',
#      'lanes': '1',
#      'maxspeed': '130',
#      'maxspeed:conditional': '110 @ wet',
#      'maxspeed:hgv:conditional': '90 @ (weight>7.5)',
#      'minspeed': '40',
#      'moped': 'no',
#      'oneway': 'yes',
#      'ref': 'A 3',
#      'surface': 'asphalt',
#      'toll': 'no'},
#     'nodes': [141905, 64693082, 11959192449, 64693083, 21277845]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.1137541, 49.5317217],
#      [6.11386, 49.5317799],
#      [6.1139378, 49.5318544],
#      [6.1139819, 49.5319398],
#      [6.113989, 49.5320297]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4016003,
#     'tags': {'destination': 'Bettembourg;Livange',
#      'destination:ref': 'N 31',
#      'highway': 'motorway_link',
#      'junction:ref': '2',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '70',
#      'oneway': 'yes',
#      'ref': 'A 3',
#      'shoulder:right': 'yes',
#      'surface': 'asphalt',
#      'toll': 'no'},
#     'nodes': [141907,
#      6331615213,
#      6331615212,
#      21277851,
#      6331615211,
#      21277852,
#      9694987715,
#      21277855]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.1137239, 49.5285054],
#      [6.1136717, 49.5290185],
#      [6.1136475, 49.5292387],
#      [6.113626, 49.5295442],
#      [6.1136341, 49.5298106],
#      [6.1136824, 49.5301266],
#      [6.1137521, 49.5304835],
#      [6.1139899, 49.5314147]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4065380,
#     'tags': {'destination': 'Trier;Ettelbruck;Echternach',
#      'destination:int_ref': 'E 44',
#      'destination:ref:to': 'A 7',
#      'highway': 'motorway_link',
#      'int_ref': 'E 29',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '130',
#      'maxspeed:conditional': '110 @ wet',
#      'maxspeed:hgv:conditional': '90 @ (weight>7.5)',
#      'oneway': 'yes',
#      'operator': 'Administration des Ponts et Chaussées',
#      'ref': 'A 1',
#      'surface': 'asphalt',
#      'toll': 'no',
#      'zone:traffic': 'LU:motorway'},
#     'nodes': [1033533780,
#      6333682802,
#      2571990375,
#      21277371,
#      2571990378,
#      309944548,
#      21277372]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.1270131, 49.5751022],
#      [6.1272034, 49.5751851],
#      [6.127422, 49.5752649],
#      [6.1276359, 49.5753303],
#      [6.1278835, 49.5753909],
#      [6.1281991, 49.5754595],
#      [6.1286481, 49.575512]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4065464,
#     'tags': {'bicycle': 'no',
#      'destination': 'Toutes directions;Aéroport',
#      'destination:ref': 'A 1;A 7',
#      'foot': 'no',
#      'highway': 'trunk_link',
#      'lanes': '2',
#      'lit': 'yes',
#      'maxspeed': '70',
#      'minspeed': '40',
#      'moped': 'no',
#      'oneway': 'yes',
#      'ref': 'N 51',
#      'surface': 'asphalt',
#      'width': '8'},
#     'nodes': [141779,
#      4446349390,
#      4446349404,
#      2574889107,
#      5316946933,
#      4384664786]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.1771817, 49.6354152],
#      [6.1772521, 49.6355815],
#      [6.1773151, 49.6356649],
#      [6.1773835, 49.635727],
#      [6.1774841, 49.6357878],
#      [6.1776879, 49.6358855]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4065556,
#     'tags': {'highway': 'motorway_link',
#      'lanes': '1',
#      'lit': 'yes',
#      'oneway': 'yes',
#      'surface': 'asphalt',
#      'toll': 'no'},
#     'nodes': [5752456623, 564173567, 141895]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.1203852, 49.5440543],
#      [6.120166, 49.5439107],
#      [6.1199462, 49.5438016]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4065646,
#     'tags': {'highway': 'service',
#      'lit': 'yes',
#      'maxspeed': '50',
#      'oneway': 'yes',
#      'service': 'driveway',
#      'surface': 'asphalt'},
#     'nodes': [2957193283,
#      1278559523,
#      1278559668,
#      622419,
#      1278559638,
#      1278559630,
#      799541894]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[5.9745317, 49.6356861],
#      [5.9739776, 49.6359279],
#      [5.9732555, 49.6363296],
#      [5.9728736, 49.6365678],
#      [5.9720036, 49.6373152],
#      [5.9719493, 49.6374036],
#      [5.9718273, 49.6375013]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4065707,
#     'tags': {'cycleway:right': 'no',
#      'highway': 'primary',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '50',
#      'name': "Route d'Arlon",
#      'name:de': 'Areler Straße',
#      'name:etymology:wikidata': 'Q675960',
#      'name:lb': 'Arelerstrooss',
#      'oneway': 'yes',
#      'ref': 'N 6',
#      'surface': 'asphalt',
#      'wikidata': 'Q61123383'},
#     'nodes': [61878530, 61878529, 678937651, 1224675127, 61878528]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0544915, 49.6221358],
#      [6.053399, 49.6221439],
#      [6.0524232, 49.6220977],
#      [6.0522324, 49.6220992],
#      [6.052075, 49.6221063]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4065736,
#     'tags': {'cycleway:right': 'no',
#      'highway': 'primary',
#      'lanes': '2',
#      'lit': 'yes',
#      'maxspeed': '50',
#      'name': 'Boulevard Royal',
#      'oneway': 'yes',
#      'ref': 'N 7',
#      'sidewalk': 'separate',
#      'surface': 'asphalt',
#      'wikidata': 'Q4949669',
#      'wikimedia_commons': 'Category:Boulevard Royal (Luxembourg City)',
#      'wikipedia': 'en:Boulevard Royal'},
#     'nodes': [141657,
#      9811011919,
#      1336108517,
#      4083208107,
#      4083208105,
#      7653269424,
#      634261478]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.13038, 49.6146225],
#      [6.1303094, 49.6146229],
#      [6.1302427, 49.6146167],
#      [6.130166, 49.6146039],
#      [6.130101, 49.6145876],
#      [6.129885, 49.6145089],
#      [6.1298083, 49.6144809]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4065877,
#     'tags': {'highway': 'motorway_link',
#      'lanes': '1',
#      'lit': 'yes',
#      'name': "Aire d'autoroute de Capellen",
#      'oneway': 'yes',
#      'ref': 'A 6',
#      'surface': 'asphalt',
#      'toll': 'no'},
#     'nodes': [269214932, 1160106907, 665497113, 269214987, 269214935]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[5.9669184, 49.6359043],
#      [5.9672198, 49.6358691],
#      [5.9674571, 49.6358267],
#      [5.9678288, 49.6357213],
#      [5.9680275, 49.6356546]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4268768,
#     'tags': {'highway': 'primary',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '50',
#      'name': 'Route de Thionville',
#      'name:etymology:wikidata': 'Q22640',
#      'oneway': 'yes',
#      'ref': 'N 3',
#      'surface': 'asphalt'},
#     'nodes': [2091595492, 1261396509, 1261396499, 247988459]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.1928642, 49.5067346],
#      [6.1928438, 49.506808],
#      [6.1928236, 49.5069099],
#      [6.1928517, 49.5070481]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4277506,
#     'tags': {'highway': 'residential',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '30',
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [25725159, 25725124]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.2555478, 49.6152094], [6.2552997, 49.6151889]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4277509,
#     'tags': {'highway': 'residential',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '30',
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [1642841021, 25725125]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.2556894, 49.6151843], [6.2557226, 49.6153899]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4277561,
#     'tags': {'highway': 'residential',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '30',
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [25725125, 25725164]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.2557226, 49.6153899], [6.2556015, 49.6152307]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4277562,
#     'tags': {'highway': 'residential',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '30',
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [25725124, 25725160]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.2552997, 49.6151889], [6.2555428, 49.6151574]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4277563,
#     'tags': {'highway': 'residential',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '30',
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [1642840977, 25725123]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.2555998, 49.6151309], [6.2556624, 49.6149748]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4277602,
#     'tags': {'bicycle': 'no',
#      'destination': 'Niederanven;Munsbach',
#      'destination:ref': 'CR 132',
#      'foot': 'no',
#      'highway': 'motorway_link',
#      'junction:ref': '11',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '70',
#      'minspeed': '40',
#      'moped': 'no',
#      'oneway': 'yes',
#      'ref': 'A 1',
#      'surface': 'asphalt',
#      'turn': 'slight_right'},
#     'nodes': [935823249,
#      935823250,
#      25725536,
#      25725535,
#      25725534,
#      1320936365,
#      25725533,
#      25725532,
#      25725530,
#      390428226,
#      25725529,
#      25725528]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.2742075, 49.642192],
#      [6.2739352, 49.6422009],
#      [6.2706136, 49.6417604],
#      [6.2702119, 49.6417641],
#      [6.2698588, 49.6418014],
#      [6.2696561, 49.6418382],
#      [6.269475, 49.6418857],
#      [6.2690967, 49.6420117],
#      [6.2679605, 49.6424529],
#      [6.2676754, 49.6425455],
#      [6.2673842, 49.6426135],
#      [6.2670685, 49.6426507]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4277604,
#     'tags': {'bicycle': 'no',
#      'destination': 'Luxembourg;Arlon;Metz',
#      'foot': 'no',
#      'hgv': 'yes',
#      'highway': 'motorway_link',
#      'junction:ref': '11',
#      'lanes': '1',
#      'maxspeed': '130',
#      'maxspeed:conditional': '110 @ wet',
#      'maxspeed:hgv:conditional': '90 @ (weight>7.5)',
#      'minspeed': '40',
#      'moped': 'no',
#      'oneway': 'yes',
#      'ref': 'A 1',
#      'surface': 'asphalt'},
#     'nodes': [25725541, 390428224, 390428225, 8278516747, 63299304]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.2651139, 49.6417151],
#      [6.2650794, 49.6418109],
#      [6.2650787, 49.6418839],
#      [6.2651132, 49.641952],
#      [6.2652337, 49.6420684]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4277605,
#     'tags': {'bicycle': 'no',
#      'destination': 'Niederanven;Munsbach',
#      'destination:ref': 'CR 132',
#      'foot': 'no',
#      'highway': 'motorway_link',
#      'junction:ref': '11',
#      'lanes': '1',
#      'lit': 'yes',
#      'minspeed': '40',
#      'moped': 'no',
#      'oneway': 'yes',
#      'ref': 'A 1',
#      'surface': 'asphalt'},
#     'nodes': [25725516, 390431971]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.2638383, 49.6403861], [6.2658387, 49.6407335]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4292102,
#     'tags': {'highway': 'unclassified',
#      'lit': 'yes',
#      'maxspeed': '30',
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [25762363, 1412986401, 1412986398, 25762365]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.2200624, 49.620142],
#      [6.2198516, 49.6201686],
#      [6.2189645, 49.6201178],
#      [6.2187826, 49.6200758]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4292108,
#     'tags': {'highway': 'residential',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '30',
#      'name': 'An de Steekaulen',
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [1423457130,
#      1423457129,
#      1423457127,
#      1423457119,
#      1413044894,
#      11254712936,
#      1423457117,
#      1423457118,
#      25907152,
#      1423457125,
#      1423457128,
#      1374177989,
#      25907154,
#      1423457131,
#      1423457132,
#      25907155,
#      1423457134,
#      1423457136,
#      1270641051,
#      1423457135,
#      1423457133,
#      25907158,
#      25907142,
#      1374178008,
#      1423457130]},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[6.2251993, 49.6165809],
#       [6.2251782, 49.6164698],
#       [6.2252141, 49.6163808],
#       [6.2252925, 49.6163168],
#       [6.2253786, 49.6162911],
#       [6.2254594, 49.6162791],
#       [6.2255429, 49.6162773],
#       [6.2256429, 49.6162926],
#       [6.2257204, 49.6163181],
#       [6.2257683, 49.6163652],
#       [6.2258154, 49.6164656],
#       [6.2258652, 49.6165826],
#       [6.225981, 49.6168529],
#       [6.2259879, 49.6169376],
#       [6.225954, 49.6170051],
#       [6.2259349, 49.6170226],
#       [6.2258515, 49.6170538],
#       [6.2257394, 49.6170823],
#       [6.2256189, 49.617089],
#       [6.2255057, 49.6170724],
#       [6.2254153, 49.6170309],
#       [6.2253635, 49.6169632],
#       [6.2253169, 49.6168555],
#       [6.2252482, 49.616694],
#       [6.2251993, 49.6165809]]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4292109,
#     'tags': {'highway': 'residential',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '30',
#      'name': 'An de Strachen',
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [25907148,
#      25907147,
#      25907145,
#      25907143,
#      1413044913,
#      25907144,
#      25907146,
#      25907148]},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[6.2239479, 49.6164441],
#       [6.2240782, 49.6165083],
#       [6.2241673, 49.6167078],
#       [6.2241179, 49.6168218],
#       [6.2240393, 49.6167719],
#       [6.2239947, 49.6167435],
#       [6.2239026, 49.616544],
#       [6.2239479, 49.6164441]]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4292132,
#     'tags': {'highway': 'residential',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '30',
#      'name': 'Rue du Pain',
#      'name:lb': 'Broutgaass',
#      'oneway': 'yes',
#      'smoothness': 'intermediate',
#      'surface': 'asphalt'},
#     'nodes': [25762200, 2597375451, 25762199]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.2153141, 49.6142248],
#      [6.2151264, 49.6142194],
#      [6.214529, 49.6141734]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4294200,
#     'tags': {'bicycle': 'no',
#      'destination': 'Schifflange;Foetz',
#      'destination:ref': 'CR 169',
#      'foot': 'no',
#      'hgv': 'yes',
#      'highway': 'motorway_link',
#      'junction:ref': '6',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '70',
#      'minspeed': '40',
#      'moped': 'no',
#      'name': 'Échangeur de Schifflange',
#      'oneway': 'yes',
#      'ref': 'A 13',
#      'surface': 'asphalt',
#      'toll': 'no'},
#     'nodes': [25922467,
#      25922984,
#      25922983,
#      25922981,
#      25922980,
#      25922979,
#      25922978,
#      25922977,
#      25922976,
#      25922975,
#      25922974]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0170607, 49.5128156],
#      [6.0166379, 49.5129345],
#      [6.0161545, 49.5130634],
#      [6.0157476, 49.5132201],
#      [6.0154562, 49.5133673],
#      [6.0152192, 49.5135258],
#      [6.0150167, 49.5137178],
#      [6.0148537, 49.5139128],
#      [6.0146525, 49.5141949],
#      [6.0145546, 49.514309],
#      [6.0144603, 49.514404]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4294201,
#     'tags': {'bicycle': 'no',
#      'foot': 'no',
#      'hgv': 'yes',
#      'highway': 'motorway_link',
#      'junction:ref': '6',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '130',
#      'maxspeed:conditional': '110 @ wet',
#      'maxspeed:hgv:conditional': '90 @ (weight>7.5)',
#      'minspeed': '40',
#      'moped': 'no',
#      'name': 'Échangeur de Schifflange',
#      'oneway': 'yes',
#      'ref': 'A 13',
#      'surface': 'asphalt',
#      'toll': 'no'},
#     'nodes': [5399172948, 5399172947, 25922996]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0128022, 49.5126084],
#      [6.0128793, 49.512608],
#      [6.0133038, 49.5125296]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4294203,
#     'tags': {'bicycle': 'no',
#      'destination': 'Schifflange;Foetz',
#      'destination:ref': 'CR 169',
#      'foot': 'no',
#      'highway': 'motorway_link',
#      'junction:ref': '6',
#      'lanes': '1',
#      'minspeed': '40',
#      'moped': 'no',
#      'name': 'Échangeur de Schifflange',
#      'oneway': 'yes',
#      'ref': 'A 13',
#      'surface': 'asphalt',
#      'toll': 'no'},
#     'nodes': [25922587,
#      589989415,
#      589989414,
#      589989413,
#      589989421,
#      589989419]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0101659, 49.5155529],
#      [6.0104998, 49.5152403],
#      [6.0109956, 49.5148966],
#      [6.0117256, 49.5144435],
#      [6.0122822, 49.5141393],
#      [6.0128103, 49.51389]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4294207,
#     'tags': {'bicycle': 'no',
#      'foot': 'no',
#      'highway': 'motorway_link',
#      'junction:ref': '7',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '130',
#      'maxspeed:bus': '90',
#      'maxspeed:conditional': '110 @ wet',
#      'maxspeed:hgv:conditional': '90 @ (weight>7.5)',
#      'maxspeed:trailer': '90',
#      'minspeed': '40',
#      'moped': 'no',
#      'oneway': 'yes',
#      'ref': 'A 13',
#      'surface': 'asphalt',
#      'toll': 'no'},
#     'nodes': [25921711,
#      25921722,
#      25921721,
#      25921720,
#      25921719,
#      2267024796,
#      25921725]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0531394, 49.500194],
#      [6.0525802, 49.5001882],
#      [6.0522444, 49.5001982],
#      [6.0518153, 49.5002261],
#      [6.051298, 49.5002869],
#      [6.0508921, 49.5003505],
#      [6.0499564, 49.5005193]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4294209,
#     'tags': {'bicycle': 'no',
#      'foot': 'no',
#      'highway': 'motorway_link',
#      'junction:ref': '7',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '130',
#      'maxspeed:bus': '90',
#      'maxspeed:conditional': '110 @ wet',
#      'maxspeed:hgv:conditional': '90 @ (weight>7.5)',
#      'maxspeed:trailer': '90',
#      'minspeed': '40',
#      'moped': 'no',
#      'oneway': 'yes',
#      'ref': 'A 13',
#      'surface': 'asphalt',
#      'toll': 'no'},
#     'nodes': [25921732, 25921748, 25921739, 25921711]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0534468, 49.4999884],
#      [6.0533723, 49.5001086],
#      [6.0532964, 49.5001668],
#      [6.0531394, 49.500194]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4294210,
#     'tags': {'bicycle': 'no',
#      'foot': 'no',
#      'highway': 'motorway_link',
#      'junction:ref': '7',
#      'lanes': '1',
#      'lit': 'yes',
#      'minspeed': '40',
#      'moped': 'no',
#      'oneway': 'yes',
#      'ref': 'A 13',
#      'surface': 'asphalt',
#      'toll': 'no'},
#     'nodes': [25921713, 25921740, 25921741, 979177387, 979177386]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0524054, 49.4994109],
#      [6.0525495, 49.4993526],
#      [6.052682, 49.4993428],
#      [6.0528022, 49.4993568],
#      [6.0529274, 49.4993873]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4294211,
#     'tags': {'bicycle': 'no',
#      'destination': 'Kayl',
#      'destination:ref': 'CR 165',
#      'foot': 'no',
#      'highway': 'motorway_link',
#      'junction:ref': '7',
#      'lanes': '1',
#      'lit': 'yes',
#      'minspeed': '40',
#      'moped': 'no',
#      'oneway': 'yes',
#      'ref': 'A 13',
#      'surface': 'asphalt',
#      'toll': 'no'},
#     'nodes': [25921607,
#      25921626,
#      947906688,
#      25921622,
#      25921620,
#      25921649,
#      25921646,
#      25921644]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0563394, 49.4993558],
#      [6.0560749, 49.4994288],
#      [6.0557713, 49.4994712],
#      [6.0554631, 49.4995293],
#      [6.0549126, 49.4996782],
#      [6.0545904, 49.4997861],
#      [6.0542015, 49.4999383],
#      [6.0539563, 49.5000661]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4294212,
#     'tags': {'bicycle': 'no',
#      'foot': 'no',
#      'highway': 'motorway_link',
#      'junction:ref': '7',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '130',
#      'maxspeed:bus': '90',
#      'maxspeed:conditional': '110 @ wet',
#      'maxspeed:hgv:conditional': '90 @ (weight>7.5)',
#      'maxspeed:trailer': '90',
#      'minspeed': '40',
#      'moped': 'no',
#      'oneway': 'yes',
#      'ref': 'A 13',
#      'surface': 'asphalt',
#      'toll': 'no'},
#     'nodes': [25921700,
#      1779200021,
#      4197467370,
#      25921745,
#      6366559637,
#      25921747]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0523204, 49.4987931],
#      [6.0526588, 49.4990354],
#      [6.0528197, 49.4991317],
#      [6.0529876, 49.4992081],
#      [6.0531276, 49.4992557],
#      [6.0532104, 49.4992839]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4294213,
#     'tags': {'bicycle': 'no',
#      'foot': 'no',
#      'highway': 'motorway_link',
#      'junction:ref': '7',
#      'lanes': '1',
#      'lit': 'yes',
#      'minspeed': '40',
#      'moped': 'no',
#      'oneway': 'yes',
#      'ref': 'A 13',
#      'surface': 'asphalt',
#      'toll': 'no'},
#     'nodes': [25921644, 25921737, 25921738, 9703417489, 25921732]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0539563, 49.5000661],
#      [6.0537572, 49.5000868],
#      [6.0536207, 49.5000708],
#      [6.0536009, 49.5000658],
#      [6.0534468, 49.4999884]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4294214,
#     'tags': {'bicycle': 'no',
#      'foot': 'no',
#      'highway': 'motorway_link',
#      'junction:ref': '7',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '130',
#      'maxspeed:conditional': '110 @ wet',
#      'maxspeed:hgv:conditional': '90 @ (weight>7.5)',
#      'minspeed': '40',
#      'moped': 'no',
#      'oneway': 'yes',
#      'ref': 'A 13',
#      'surface': 'asphalt',
#      'toll': 'no'},
#     'nodes': [25921731, 1779200020, 567937531, 25921747]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0529712, 49.499435],
#      [6.0530233, 49.4993784],
#      [6.0530643, 49.4993335],
#      [6.0532104, 49.4992839]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4294261,
#     'tags': {'highway': 'unclassified',
#      'maxspeed': '50',
#      'name': "Zone d'Activité Économique Wolser B",
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [25921458, 2285532439, 567940765, 3422085738, 25921379]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0893496, 49.5037765],
#      [6.0891388, 49.5037661],
#      [6.0890648, 49.5037631],
#      [6.0889167, 49.5037317],
#      [6.0887223, 49.5036176]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4294263,
#     'tags': {'highway': 'residential',
#      'name': "Zone d'Activité Économique Wolser B",
#      'oneway': 'yes'},
#     'nodes': [25921477, 25921393]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0876326, 49.5028729], [6.087714, 49.5027484]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4294264,
#     'tags': {'highway': 'unclassified',
#      'maxspeed': '50',
#      'name': "Zone d'Activité Économique Wolser B",
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [25921391, 567940762, 5468395314, 25921473]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0882037, 49.5031458],
#      [6.0880874, 49.5031115],
#      [6.0879922, 49.503105],
#      [6.0878969, 49.5031232]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4294265,
#     'tags': {'highway': 'unclassified',
#      'maxspeed': '50',
#      'name': "Zone d'Activité Économique Wolser B",
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [25921472, 25921396]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0878233, 49.5031979], [6.0878534, 49.5033964]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4294266,
#     'tags': {'highway': 'unclassified',
#      'maxspeed': '50',
#      'name': "Zone d'Activité Économique Wolser B",
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [25921396, 7555137182, 25921471]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0878534, 49.5033964],
#      [6.0877999, 49.5033548],
#      [6.0876633, 49.5032486]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4309856,
#     'tags': {'highway': 'residential',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '30',
#      'name': 'Rue Jean',
#      'name:lb': 'Kräizgaart',
#      'oneway': 'yes',
#      'oneway:bicycle': 'no',
#      'surface': 'asphalt'},
#     'nodes': [25924581, 6189927801, 8615294703, 25924582]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0938848, 49.516769],
#      [6.0940067, 49.5167936],
#      [6.0947702, 49.5169477],
#      [6.0952181, 49.5170381]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4309857,
#     'tags': {'highway': 'residential',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '30',
#      'name': 'Rue Adolphe',
#      'name:etymology:wikidata': 'Q57302',
#      'oneway': 'yes',
#      'oneway:bicycle': 'no',
#      'sidewalk': 'both',
#      'surface': 'asphalt'},
#     'nodes': [25924580, 5892683029, 25924579]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.095495, 49.5164377],
#      [6.0942875, 49.5162111],
#      [6.0941617, 49.5161875]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4309860,
#     'tags': {'foot': 'no',
#      'hgv': 'yes',
#      'highway': 'primary',
#      'lanes': '1',
#      'lit': 'yes',
#      'oneway': 'yes',
#      'ref': 'N 31',
#      'surface': 'asphalt'},
#     'nodes': [25921460, 25921374, 6902362700, 25921380]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0893388, 49.5034988],
#      [6.0893435, 49.5033741],
#      [6.0893092, 49.5033066],
#      [6.0891355, 49.5030778]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4309861,
#     'tags': {'foot': 'no',
#      'highway': 'primary',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '50',
#      'oneway': 'yes',
#      'ref': 'N 31',
#      'surface': 'asphalt'},
#     'nodes': [25921464, 1160002398, 5056404147, 1160002367, 25921376]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0898007, 49.5037501],
#      [6.0898346, 49.5038586],
#      [6.0898809, 49.5039343],
#      [6.0906934, 49.5049839],
#      [6.0909581, 49.5053835]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4309862,
#     'tags': {'foot': 'no',
#      'highway': 'primary',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '50',
#      'oneway': 'yes',
#      'ref': 'N 31',
#      'surface': 'asphalt'},
#     'nodes': [25921376, 1160002396, 5056404145, 567940779, 25921465]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0909581, 49.5053835],
#      [6.0906221, 49.5050214],
#      [6.089796, 49.503958],
#      [6.0897276, 49.5038966],
#      [6.0895891, 49.5038291]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4309882,
#     'tags': {'highway': 'residential',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '30',
#      'name': 'Rue Paul Eyschen',
#      'name:etymology:wikidata': 'Q945406',
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [25925190, 2960707383, 25925209]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0998807, 49.5180509],
#      [6.0997573, 49.5180553],
#      [6.0988696, 49.5179255]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4309895,
#     'tags': {'highway': 'residential',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '30',
#      'name': 'Rue des Roses',
#      'name:etymology:wikidata': 'Q64140922',
#      'oneway': 'yes',
#      'oneway:bicycle': 'no',
#      'surface': 'asphalt'},
#     'nodes': [25924995, 9632849464, 25924994]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0995783, 49.519451],
#      [6.1001359, 49.5197368],
#      [6.1002498, 49.5197951]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4309899,
#     'tags': {'highway': 'primary',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '50',
#      'name': 'Route des Trois Cantons',
#      'name:de': 'Dreikantonstraße',
#      'name:fr': 'Route des Trois Cantons',
#      'name:lb': 'Dräikantonstrooss',
#      'oneway': 'yes',
#      'ref': 'N 13',
#      'surface': 'asphalt'},
#     'nodes': [943631314, 946797463, 9767911820, 946797452]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.1024653, 49.5161299],
#      [6.1027422, 49.5161626],
#      [6.1028211, 49.5161516],
#      [6.1028963, 49.516129]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4309907,
#     'tags': {'highway': 'residential',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '30',
#      'name': 'Rue du Nord',
#      'oneway': 'yes',
#      'oneway:bicycle': 'no',
#      'surface': 'asphalt'},
#     'nodes': [25924993,
#      3312845617,
#      3312845608,
#      7425922527,
#      7350446926,
#      5318579634,
#      25925220]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0995677, 49.5203372],
#      [6.0996635, 49.5204089],
#      [6.1000043, 49.5206636],
#      [6.1001667, 49.520785],
#      [6.1006712, 49.521162],
#      [6.1008587, 49.5213265],
#      [6.1009547, 49.5214517]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4309914,
#     'tags': {'foot': 'no',
#      'hgv': 'yes',
#      'highway': 'service',
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [25921462, 4652051663, 1930430392, 1930430396, 4652990951]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0897735, 49.5034973],
#      [6.0899452, 49.5034792],
#      [6.0901058, 49.5034542],
#      [6.0902587, 49.5034438],
#      [6.0905053, 49.5034486]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4309915,
#     'tags': {'hgv': 'yes',
#      'highway': 'service',
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [25921377,
#      4652990950,
#      1930430401,
#      1930430405,
#      426430547,
#      25921463]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0910255, 49.503559],
#      [6.0904363, 49.5035061],
#      [6.0902588, 49.5035046],
#      [6.0901313, 49.503513],
#      [6.0899975, 49.5035461],
#      [6.0898583, 49.5036494]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4310010,
#     'tags': {'bicycle': 'no',
#      'destination': 'Metz',
#      'destination:lanes': 'Metz;Thionville;Dudelange-Centre',
#      'destination:ref': 'A 3',
#      'foot': 'no',
#      'hgv': 'yes',
#      'highway': 'motorway_link',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '130',
#      'maxspeed:conditional': '110 @ wet',
#      'maxspeed:hgv:conditional': '90 @ (weight>7.5)',
#      'minspeed': '40',
#      'moped': 'no',
#      'oneway': 'yes',
#      'operator': 'Administration des Ponts et Chaussées',
#      'ref': 'A 13',
#      'surface': 'asphalt',
#      'toll': 'no',
#      'zone:traffic': 'LU:motorway'},
#     'nodes': [25920882,
#      25920895,
#      978476301,
#      25920897,
#      8318340213,
#      1885214705,
#      25920898,
#      25920899,
#      1885214708,
#      25920900,
#      25920901,
#      1885214721,
#      25920902,
#      1885214726,
#      25920903,
#      25920904,
#      1885214728,
#      25920905,
#      25920906,
#      1885214723,
#      8741880208,
#      339883385,
#      25920908,
#      25920909]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.116063, 49.4968394],
#      [6.1157008, 49.4968331],
#      [6.1154956, 49.4968592],
#      [6.1153346, 49.4969036],
#      [6.1152165, 49.4969636],
#      [6.115112, 49.4970421],
#      [6.1150315, 49.4971449],
#      [6.1149833, 49.4972729],
#      [6.1149712, 49.4973992],
#      [6.1149967, 49.4975203],
#      [6.1150671, 49.4976592],
#      [6.1151589, 49.4977677],
#      [6.115301, 49.4978787],
#      [6.1154465, 49.497956],
#      [6.1156016, 49.4980105],
#      [6.1157755, 49.4980439],
#      [6.1159249, 49.4980485],
#      [6.1160571, 49.4980349],
#      [6.1162183, 49.497993],
#      [6.1163581, 49.4979279],
#      [6.1164419, 49.4978686],
#      [6.1165511, 49.4977447],
#      [6.1166124, 49.4976271],
#      [6.1167142, 49.4973249]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4310011,
#     'tags': {'bicycle': 'no',
#      'destination': 'Esch-sur-Alzette;Dudelange-Burange',
#      'destination:ref': 'A 3;A 13',
#      'foot': 'no',
#      'highway': 'motorway_link',
#      'lit': 'yes',
#      'maxspeed': '130',
#      'maxspeed:hgv:conditional': '90 @ (weight>7.5)',
#      'minspeed': '40',
#      'moped': 'no',
#      'oneway': 'yes',
#      'operator': 'Administration des Ponts et Chaussées',
#      'ref': 'A 3',
#      'surface': 'asphalt',
#      'toll': 'no',
#      'zone:traffic': 'LU:motorway'},
#     'nodes': [622466,
#      1885214707,
#      7615604269,
#      646808906,
#      7615604258,
#      25920894,
#      7615604255,
#      7615604251,
#      25920893,
#      25920892,
#      1885214739,
#      25920891,
#      1885214741,
#      25920890,
#      1885214742,
#      25920889,
#      25920888,
#      1885214738,
#      25920887,
#      644574335,
#      25920886,
#      1239480522,
#      25920885,
#      1885214709,
#      25920884,
#      25920883,
#      25920881]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.1171317, 49.4966205],
#      [6.117117, 49.4972877],
#      [6.1171177, 49.4974942],
#      [6.1171387, 49.4976831],
#      [6.1171702, 49.4978231],
#      [6.1172038, 49.4979379],
#      [6.1172518, 49.4980397],
#      [6.117314, 49.4981265],
#      [6.1174081, 49.4982148],
#      [6.1175114, 49.4982826],
#      [6.1176044, 49.4983278],
#      [6.117749, 49.4983773],
#      [6.1178745, 49.4984043],
#      [6.1180203, 49.4984182],
#      [6.1182154, 49.4984107],
#      [6.1184079, 49.4983751],
#      [6.1185748, 49.4983137],
#      [6.1187046, 49.4982385],
#      [6.1188413, 49.4981137],
#      [6.1189204, 49.4979643],
#      [6.118932, 49.497846],
#      [6.1189152, 49.4977218],
#      [6.1188428, 49.4975939],
#      [6.1187567, 49.4975143],
#      [6.1186566, 49.4974434],
#      [6.1184079, 49.4973249],
#      [6.1179698, 49.4971851]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4310013,
#     'tags': {'bicycle': 'no',
#      'destination:ref': 'A 3',
#      'foot': 'no',
#      'hgv': 'yes',
#      'highway': 'motorway_link',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '130',
#      'maxspeed:bus': '90',
#      'maxspeed:conditional': '110 @ wet',
#      'maxspeed:hgv:conditional': '90 @ (weight>7.5)',
#      'maxspeed:trailer': '90',
#      'minspeed': '40',
#      'moped': 'no',
#      'oneway': 'yes',
#      'operator': 'Administration des Ponts et Chaussées',
#      'ref': 'A 3',
#      'surface': 'asphalt',
#      'toll': 'no',
#      'zone:traffic': 'LU:motorway'},
#     'nodes': [25921125, 25920986, 25920985, 2624373289, 25920984]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.1114329, 49.4961732],
#      [6.112283, 49.4961428],
#      [6.1130984, 49.4961428],
#      [6.113479, 49.4961114],
#      [6.113784, 49.496072]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4310015,
#     'tags': {'bicycle': 'no',
#      'destination': 'Luxembourg',
#      'destination:ref': 'A 3',
#      'foot': 'no',
#      'highway': 'motorway_link',
#      'lanes': '2',
#      'lit': 'yes',
#      'maxspeed': '130',
#      'maxspeed:conditional': '110 @ wet',
#      'maxspeed:hgv:conditional': '90 @ (weight>7.5)',
#      'minspeed': '40',
#      'moped': 'no',
#      'oneway': 'yes',
#      'operator': 'Administration des Ponts et Chaussées',
#      'ref': 'A 3',
#      'surface': 'asphalt',
#      'toll': 'no',
#      'zone:traffic': 'LU:motorway'},
#     'nodes': [25920948,
#      25920949,
#      1885214667,
#      25920951,
#      25920952,
#      1885214665,
#      305885874]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.1148113, 49.4957111],
#      [6.1153033, 49.4954798],
#      [6.1155231, 49.4953906],
#      [6.1158342, 49.4952927],
#      [6.1160505, 49.495243],
#      [6.1162915, 49.4952068],
#      [6.1166207, 49.4951772]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4310045,
#     'tags': {'highway': 'secondary',
#      'lanes': '1',
#      'maxspeed': '50',
#      'oneway': 'yes',
#      'ref': 'CR 169',
#      'surface': 'asphalt'},
#     'nodes': [25922364, 2619483445, 589991450]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0111073, 49.5092044],
#      [6.0110074, 49.5092947],
#      [6.0109444, 49.5093781]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4310046,
#     'tags': {'highway': 'secondary',
#      'lanes': '2',
#      'maxspeed': '50',
#      'oneway': 'yes',
#      'ref': 'CR 169',
#      'surface': 'asphalt'},
#     'nodes': [3866184309,
#      3867879339,
#      9561530475,
#      1308240266,
#      1308240269,
#      1308240258,
#      1308240257,
#      589991445]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.011418, 49.5103754],
#      [6.0112502, 49.5101015],
#      [6.0111583, 49.5099617],
#      [6.0109665, 49.5097488],
#      [6.0108961, 49.5096443],
#      [6.0108646, 49.5095581],
#      [6.0108512, 49.509471],
#      [6.0108629, 49.5093785]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4310047,
#     'tags': {'highway': 'tertiary', 'oneway': 'yes', 'surface': 'asphalt'},
#     'nodes': [25922359, 2519167402, 3867860332]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0110914, 49.508882],
#      [6.0111838, 49.5088087],
#      [6.011265, 49.5087034]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4310048,
#     'tags': {'highway': 'tertiary', 'oneway': 'yes', 'surface': 'asphalt'},
#     'nodes': [3867860332, 25922361]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.011265, 49.5087034], [6.0112793, 49.5089483]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4310049,
#     'tags': {'highway': 'secondary',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '50',
#      'oneway': 'yes',
#      'ref': 'CR 168',
#      'surface': 'asphalt'},
#     'nodes': [25922362, 2619483440, 25922281]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0113228, 49.5090137],
#      [6.0114436, 49.5091059],
#      [6.0115824, 49.5092045]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4310050,
#     'tags': {'highway': 'secondary',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '50',
#      'oneway': 'yes',
#      'ref': 'CR 168',
#      'surface': 'asphalt'},
#     'nodes': [25922281, 1308240265, 3866184310, 25922363]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0115824, 49.5092045],
#      [6.0114032, 49.5091848],
#      [6.0113521, 49.5091828],
#      [6.011216, 49.5091784]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4823588,
#     'tags': {'foot': 'no',
#      'highway': 'primary',
#      'lanes': '2',
#      'lit': 'yes',
#      'maxspeed': '50',
#      'name': 'Boulevard de la Foire',
#      'name:etymology:wikidata': 'Q350787',
#      'oneway': 'yes',
#      'ref': 'N 51',
#      'sidewalk:left': 'no',
#      'sidewalk:right': 'separate',
#      'surface': 'asphalt',
#      'wikidata': 'Q25583685'},
#     'nodes': [9864393693, 4887471518, 4887471517]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.1228981, 49.6155755],
#      [6.123015, 49.6156226],
#      [6.1232721, 49.6157325]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4823593,
#     'tags': {'bicycle': 'no',
#      'destination': 'Luxembourg-Centre;Plateau de Kirchberg',
#      'destination:ref': 'N 51',
#      'foot': 'no',
#      'highway': 'motorway_link',
#      'junction:ref': '8',
#      'lanes': '2',
#      'lit': 'yes',
#      'maxspeed': '90',
#      'minspeed': '40',
#      'moped': 'no',
#      'name': 'Échangeur de Kirchberg',
#      'oneway': 'yes',
#      'surface': 'asphalt',
#      'toll': 'no'},
#     'nodes': [31001770, 8638674490, 340415010]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.1932576, 49.6411638],
#      [6.1925244, 49.6410881],
#      [6.1883819, 49.6402515]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4823594,
#     'tags': {'bicycle': 'no',
#      'destination': 'Ettelbrück;Echternach;Luxembourg-Centre;Plateau de Kirchberg',
#      'destination:ref': 'A 7;N 51',
#      'foot': 'no',
#      'hgv': 'yes',
#      'highway': 'motorway_link',
#      'int_ref': 'E 29',
#      'junction:ref': '8',
#      'lanes': '2',
#      'lit': 'yes',
#      'maxspeed': '90',
#      'maxspeed:hgv:conditional': '75 @ (weight>7.5)',
#      'minspeed': '40',
#      'moped': 'no',
#      'oneway': 'yes',
#      'operator': 'Administration des Ponts et Chaussées',
#      'ref': 'A 7',
#      'surface': 'asphalt',
#      'toll': 'no',
#      'zone:traffic': 'LU:motorway'},
#     'nodes': [21278345,
#      1786292818,
#      1786292819,
#      1786292822,
#      1786292833,
#      1786292835,
#      1786292840,
#      1786292843,
#      31001843,
#      1786292846,
#      31001871,
#      1786292849,
#      1786292851,
#      265207230]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.1821645, 49.6280748],
#      [6.1822987, 49.6285213],
#      [6.1823094, 49.6289582],
#      [6.1822624, 49.6297626],
#      [6.1821662, 49.6304833],
#      [6.1820229, 49.6313509],
#      [6.1820103, 49.6314902],
#      [6.182005, 49.6316233],
#      [6.182017, 49.6317571],
#      [6.1820502, 49.6318927],
#      [6.1820935, 49.6320237],
#      [6.1821576, 49.6321532],
#      [6.1822276, 49.6322669],
#      [6.1823121, 49.6323746]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 4971721,
#     'tags': {'hgv': 'destination',
#      'highway': 'secondary',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '50',
#      'name': 'Rue Principale',
#      'oneway': 'yes',
#      'ref': 'CR 132',
#      'sidewalk': 'right',
#      'surface': 'asphalt'},
#     'nodes': [25725352, 428127289, 25725378]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.2669016, 49.633526],
#      [6.2668384, 49.6334129],
#      [6.2667829, 49.6333179]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 5016850,
#     'tags': {'bicycle': 'no',
#      'destination': 'Mondercange;Foetz',
#      'destination:ref': 'CR 164',
#      'foot': 'no',
#      'highway': 'motorway_link',
#      'junction:ref': '4',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '50',
#      'minspeed': '40',
#      'moped': 'no',
#      'name': 'Échangeur de Foetz',
#      'oneway': 'yes',
#      'ref': 'A 4',
#      'surface': 'asphalt',
#      'toll': 'no'},
#     'nodes': [25922831,
#      25922832,
#      25922852,
#      355840687,
#      25922853,
#      974695857,
#      25922854,
#      355840689,
#      25922855,
#      25922856,
#      25922857,
#      25922858,
# ...
#      8006574601,
#      1611419371,
#      278943359,
#      278943358,
#      278943357,
#      278943356,
#      1611419370,
#      278943355,
#      1611419368,
#      278943354,
#      278943353,
#      1611419366,
#      278943352,
#      278943351,
#      1611419364,
#      278943350,
#      278943349,
#      1611419362,
#      278943348,
#      1611419361,
#      278943347,
#      329223629,
#      1611419352,
#      278943346,
#      1611419350,
#      10152163522,
#      278943345]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.1348437, 49.9993942],
#      [6.1347505, 49.9993631],
#      [6.1346358, 49.9993468],
#      [6.1338365, 49.9992902],
#      [6.1326872, 49.9992761],
#      [6.1324874, 49.9992623],
#      [6.1323023, 49.9992261],
#      [6.1319657, 49.9990916],
#      [6.1318248, 49.9990597],
#      [6.1316796, 49.999057],
#      [6.1315033, 49.9990918],
#      [6.1312583, 49.9991923],
#      [6.1309663, 49.9992817],
#      [6.1294408, 49.9994881],
#      [6.1289579, 49.9994952],
#      [6.1283165, 49.9994528],
#      [6.1279705, 49.999389],
#      [6.1276205, 49.9992787],
#      [6.1273576, 49.9991649],
#      [6.126965, 49.9989353],
#      [6.1267442, 49.998835],
#      [6.1264673, 49.998746],
#      [6.126258, 49.9987028],
#      [6.1259415, 49.9986889],
#      [6.125704, 49.9987054],
#      [6.1255673, 49.998695],
#      [6.1254492, 49.998645],
#      [6.1253741, 49.9985381],
#      [6.1253205, 49.998364],
#      [6.1253124, 49.9981847],
#      [6.1253452, 49.9979789],
#      [6.1253715, 49.997814],
#      [6.1253527, 49.9975192],
#      [6.1253178, 49.9972709],
#      [6.1252373, 49.9969554],
#      [6.1251247, 49.9966295],
#      [6.1249892, 49.9963433],
#      [6.1249222, 49.9961622],
#      [6.1249187, 49.9960209],
#      [6.1249182, 49.9960019],
#      [6.1249718, 49.995871],
#      [6.1250854, 49.9957768],
#      [6.1252619, 49.9957175],
#      [6.1257082, 49.995616],
#      [6.1258569, 49.9955596],
#      [6.126489, 49.9952708],
#      [6.1265969, 49.9952147],
#      [6.1266935, 49.9951486],
#      [6.126798, 49.9950245],
#      [6.1268329, 49.9949061],
#      [6.1268181, 49.9947946],
#      [6.1267814, 49.9946593],
#      [6.126788, 49.9945544],
#      [6.1268484, 49.9944441],
#      [6.1270027, 49.9943211],
#      [6.1272022, 49.9942206],
#      [6.1274689, 49.9941271],
#      [6.1277765, 49.9940623],
#      [6.1280872, 49.9940209],
#      [6.1284127, 49.9939916],
#      [6.1290225, 49.9939781],
#      [6.1292933, 49.9939518],
#      [6.1295312, 49.9939123],
#      [6.1297286, 49.9938506],
#      [6.1299149, 49.9937696],
#      [6.1301699, 49.9936106],
#      [6.1302884, 49.9935076],
#      [6.1303636, 49.993398],
#      [6.1305454, 49.9931115],
#      [6.1306179, 49.9929714],
#      [6.1306487, 49.992749]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 26279087,
#     'tags': {'highway': 'residential',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '30',
#      'name': 'Rue des Romains',
#      'name:etymology:wikidata': 'Q1747689',
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [287849450,
#      1594859631,
#      1335413005,
#      1335413000,
#      11805396864,
#      287849496,
#      1335413001,
#      287849498,
#      1335412987,
#      287849499,
#      442656788,
#      287849500,
#      287849501,
#      1335413003,
#      287849447]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0968014, 49.8483917],
#      [6.096965, 49.8482239],
#      [6.0970083, 49.8481503],
#      [6.0970137, 49.8480702],
#      [6.0969965, 49.8479991],
#      [6.0969699, 49.8479505],
#      [6.0965945, 49.8476278],
#      [6.0965617, 49.8475796],
#      [6.0965618, 49.8475362],
#      [6.0965903, 49.8474938],
#      [6.0966628, 49.8474709],
#      [6.0967584, 49.8474789],
#      [6.0969615, 49.8475286],
#      [6.0971171, 49.8475951],
#      [6.0972478, 49.8476772]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 26336390,
#     'tags': {'highway': 'residential',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '30',
#      'name': 'Rue Bernard Haal',
#      'name:etymology:wikidata': 'Q16439347',
#      'oneway': 'yes',
#      'sidewalk': 'no',
#      'surface': 'asphalt',
#      'width': '5.8 m',
#      'wikidata': 'Q61123337'},
#     'nodes': [288540669, 4196740708, 252020708]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.1117617, 49.6081764],
#      [6.1117993, 49.6082748],
#      [6.1120249, 49.6090713]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 26336393,
#     'tags': {'highway': 'residential',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '30',
#      'name': 'Rue des Franciscaines',
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [252020847,
#      568060357,
#      9523177814,
#      252020710,
#      9523177812,
#      528191451,
#      71248322]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.1136107, 49.60837],
#      [6.113627, 49.6084787],
#      [6.1137565, 49.60936],
#      [6.1137682, 49.6094397],
#      [6.113782, 49.6095336],
#      [6.1138753, 49.6101673],
#      [6.1138881, 49.6102554]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 26355596,
#     'tags': {'foot': 'no',
#      'highway': 'secondary',
#      'lit': 'yes',
#      'maxspeed': '30',
#      'name': 'Boulevard Docteur Charles Marx',
#      'name:etymology:wikidata': 'Q2025919',
#      'oneway': 'yes',
#      'ref': 'CR 222',
#      'surface': 'asphalt'},
#     'nodes': [288757179, 9329640568, 492791567, 4441851286, 1111535316]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.1222537, 49.5996287],
#      [6.1222782, 49.5997032],
#      [6.1223179, 49.5997561],
#      [6.1223774, 49.5997964],
#      [6.1224608, 49.5998247]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 26361524,
#     'tags': {'highway': 'service',
#      'oneway': 'yes',
#      'sidewalk': 'right',
#      'surface': 'asphalt'},
#     'nodes': [288821634,
#      9277534099,
#      9277534098,
#      289110840,
#      1163716692,
#      1163716732,
#      9277534109,
#      288821528,
#      1163716646,
#      1163716677,
#      9277534103,
#      1163716698,
#      3677383537,
#      1163716690,
#      10673826143]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0040598, 49.5018656],
#      [6.0041378, 49.5018698],
#      [6.0042088, 49.5018912],
#      [6.0042644, 49.5019269],
#      [6.0046632, 49.5021849],
#      [6.0050426, 49.5024303],
#      [6.0053773, 49.5026468],
#      [6.0054556, 49.502697],
#      [6.0055061, 49.5027176],
#      [6.0055657, 49.5027185],
#      [6.0056177, 49.5026995],
#      [6.0056475, 49.502666],
#      [6.0056466, 49.5026272],
#      [6.0056154, 49.5025942],
#      [6.0055671, 49.5025651]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 26388013,
#     'tags': {'cycleway': 'opposite',
#      'highway': 'unclassified',
#      'maxspeed': '50',
#      'name': 'Rue du Fort Thüngen',
#      'name:etymology:wikidata': 'Q585990',
#      'oneway': 'yes',
#      'oneway:bicycle': 'no',
#      'operator': 'FUAK',
#      'ref': 'FK 5',
#      'surface': 'asphalt'},
#     'nodes': [289090471,
#      2370759517,
#      6840210980,
#      289090531,
#      6840210972,
#      1851276909,
#      5573513438,
#      1851276907,
#      289090529]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.1421122, 49.6169553],
#      [6.1417628, 49.6168909],
#      [6.1416991, 49.6168692],
#      [6.1416511, 49.6168345],
#      [6.1416246, 49.6167911],
#      [6.1416232, 49.6167445],
#      [6.1416469, 49.6167004],
#      [6.1416927, 49.6166645],
#      [6.1417531, 49.6166417]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 26388835,
#     'tags': {'highway': 'residential',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '50',
#      'name': 'Huserknapp',
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [289413589, 1366429300, 1366429299, 289100864, 289100916]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.085349, 50.0925332],
#      [6.0856849, 50.0923986],
#      [6.0857649, 50.0923789],
#      [6.0858731, 50.0923763],
#      [6.0860001, 50.0924151]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 26388844,
#     'tags': {'highway': 'residential',
#      'lanes': '1',
#      'maxspeed': '50',
#      'name': 'Beim Wasserturm',
#      'name:de': 'Beim Wasserturm',
#      'name:lb': 'Beim Waassertuerm',
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [289101061,
#      289101060,
#      8375450836,
#      289101063,
#      8375450837,
#      8375377386,
#      289101064,
#      289101065,
#      289101066]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0862208, 50.0991458],
#      [6.0862785, 50.0991922],
#      [6.0863002, 50.0992484],
#      [6.0863028, 50.0993015],
#      [6.0862541, 50.0994213],
#      [6.0859439, 50.1001843],
#      [6.0859291, 50.1002207],
#      [6.085677, 50.1006633],
#      [6.085596, 50.1008973]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 26432941,
#     'tags': {'foot': 'no',
#      'highway': 'primary',
#      'lanes': '1',
#      'maxspeed': '90',
#      'oneway': 'yes',
#      'operator': 'Administration des Ponts et Chaussées',
#      'ref': 'N 34',
#      'surface': 'asphalt'},
#     'nodes': [1036078168, 390831042, 289641879, 1036078083, 936321298]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0604455, 49.6152939],
#      [6.0602548, 49.6152807],
#      [6.0592048, 49.6154538],
#      [6.0587373, 49.6155111],
#      [6.0583473, 49.615504]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 26432947,
#     'tags': {'cycleway:right': 'no',
#      'foot': 'no',
#      'highway': 'primary',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '90',
#      'oneway': 'yes',
#      'operator': 'Administration des Ponts et Chaussées',
#      'ref': 'N 34',
#      'surface': 'asphalt'},
#     'nodes': [289641926, 1382915308, 1036077999, 6038978431, 9905005989]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.052227, 49.6203609],
#      [6.0522232, 49.6205997],
#      [6.0521678, 49.6209929],
#      [6.0520908, 49.6215539],
#      [6.0520471, 49.6217252]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 26432970,
#     'tags': {'highway': 'secondary',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '50',
#      'name': 'Rue de Luxembourg',
#      'name:lb': 'Um Riichterwee',
#      'oneway': 'yes',
#      'ref': 'CR 181',
#      'sidewalk': 'right',
#      'surface': 'asphalt'},
#     'nodes': [633219145, 633219142]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0602326, 49.6114258], [6.060113, 49.6114902]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 26449524,
#     'tags': {'hgv': 'yes',
#      'highway': 'secondary',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '90',
#      'maxspeed:bus': '75',
#      'maxspeed:hgv:conditional': '75 @ (weight>7.5)',
#      'maxspeed:trailer': '75',
#      'oneway': 'yes',
#      'ref': 'CR 234',
#      'surface': 'asphalt'},
#     'nodes': [181302550, 1219618119, 181302564]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.217177, 49.5893172],
#      [6.2170566, 49.5894273],
#      [6.2168438, 49.5897577]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 26449602,
#     'tags': {'highway': 'residential',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '30',
#      'name': 'Schlassgewan',
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [25725111, 25725154]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.2556854, 49.6141382], [6.2556882, 49.6142714]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 26450669,
#     'tags': {'bicycle': 'yes',
#      'bicycle:conditional': 'no @ (Mo-Sa 10:00-18:00)',
#      'cycleway': 'opposite',
#      'highway': 'pedestrian',
#      'lit': 'yes',
#      'maxspeed': '20',
#      'mofa': 'no',
#      'moped': 'no',
#      'motor_vehicle:conditional': 'delivery @ (06:00-10:00,18:00-22:00)',
#      'name': 'Rue Louvigny',
#      'name:etymology:wikidata': 'Q13103240',
#      'name:lb': 'Louvignysgaass',
#      'oneway': 'yes',
#      'oneway:bicycle': 'no',
#      'smoothness': 'good',
#      'surface': 'paving_stones',
#      'wikidata': 'Q61123309'},
#     'nodes': [7653258173, 74994572]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.1280363, 49.6103957], [6.1296409, 49.6105009]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 26451136,
#     'tags': {'agricultural': 'no',
#      'bicycle': 'no',
#      'destination': 'Clervaux;Diekirch;Wiltz;Ettelbruck',
#      'destination:ref': 'N 18;N 7;N 26',
#      'highway': 'trunk_link',
#      'junction:ref': '7',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '50',
#      'oneway': 'yes',
#      'ref': 'N 7',
#      'sidewalk': 'no',
#      'surface': 'asphalt'},
#     'nodes': [61752771,
#      8634262586,
#      289879052,
#      8634262579,
#      401823583,
#      7272894657]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.0987238, 49.8204152],
#      [6.098709, 49.8209547],
#      [6.0987158, 49.8211745],
#      [6.0987476, 49.8213969],
#      [6.0987835, 49.8216302],
#      [6.0987988, 49.8217196]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 26452358,
#     'tags': {'highway': 'residential',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '30',
#      'name': 'Rue de la Libération',
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [413495583, 8835228955, 289892403]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.2842179, 49.5062927],
#      [6.2858112, 49.506757],
#      [6.2858881, 49.5067794]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 26452636,
#     'tags': {'highway': 'unclassified',
#      'lanes': '1',
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [1028793368, 1028793383]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.1353388, 49.6679945], [6.1351598, 49.6680548]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 26452701,
#     'tags': {'alt_name': 'Rue Toni Erpelding',
#      'highway': 'residential',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '30',
#      'name': 'Rue Tony Erpelding',
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [289895658,
#      4879923787,
#      3402249656,
#      3402249657,
#      4879923786,
#      3402249658,
#      4879923785,
#      3402249659,
#      3402249655,
#      4879923784,
#      3402249661,
#      3402249662,
#      4879923789,
#      3402249663,
#      4879923788,
#      289895658]},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[6.1310048, 49.6711986],
#       [6.1310248, 49.6712156],
#       [6.1310418, 49.6712494],
#       [6.1310617, 49.6713486],
#       [6.1310582, 49.6713773],
#       [6.1310308, 49.6714024],
#       [6.1309944, 49.6714135],
#       [6.1309486, 49.6714116],
#       [6.1309144, 49.6713975],
#       [6.1308965, 49.6713796],
#       [6.1308904, 49.6713625],
#       [6.1308674, 49.6712622],
#       [6.1308703, 49.67123],
#       [6.1308967, 49.6712055],
#       [6.130945, 49.6711925],
#       [6.1310048, 49.6711986]]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 26453567,
#     'tags': {'highway': 'residential',
#      'lanes': '1',
#      'lit': 'yes',
#      'name': 'Op der Ho',
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [289905700, 7793862209, 7793862208]},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.2247015, 49.9135455],
#      [6.22466, 49.9137745],
#      [6.2246587, 49.913842]]}},
#   {'type': 'Feature',
#    'properties': {'type': 'way',
#     'id': 26474812,
#     'tags': {'highway': 'residential',
#      'lanes': '1',
#      'lit': 'yes',
#      'maxspeed': '30',
#      'name': 'Rue General Major Lunsford E. Oliver',
#      'name:etymology:wikidata': 'Q6704448',
#      'oneway': 'yes',
#      'surface': 'asphalt'},
#     'nodes': [290139908,
#      1769181299,
#      1769181298,
#      1769181297,
#      1769181296,
#      1769181294,
#      1769181295,
#      290139908]},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[6.0990189, 49.6079073],
#       [6.0989266, 49.6079387],
#       [6.0987141, 49.6079222],
#       [6.0986539, 49.6078976],
#       [6.0986634, 49.6078503],
#       [6.0987286, 49.6078272],
#       [6.0989551, 49.6078462],
#       [6.0990189, 49.6079073]]]}},
#   ...]}
